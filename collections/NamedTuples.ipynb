# %%
from collections import namedtuple

# %%
val1 = (1,4,5)
val2 = (4,1,5)
val3 = (3, (6,7,9))

a,(b,c,d) = val3

print(a,b,c,d)
# Out:
# 3 6 7 9

# %%
point = namedtuple('point',['first','second'])
val1 = point(7,9)
print(val1)
# Out:
# point(first=7, second=9)

# %%
val1.first=10
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 val1.first=10
#
# AttributeError: can't set attribute

# %%
point = namedtuple('point',['first','second'])
nestedpoints = namedtuple('nestedpoints',['first','second'])
val1 = nestedpoints(7, 9)
print(val1)
# Out:
# nestedpoints(first=7, second=9)
