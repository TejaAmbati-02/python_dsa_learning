# %%
arr = [15, 6, 8, 7]
print(sum(arr))
print(sum(arr, start=10))
# Out:
# 36
# 46

# %%
from math import prod
print(prod(arr))
arr = [1,2,4]
print(prod(arr))
# Out:
# 5040
# 8

# %%
print(len(arr))
# Out:
# 3

# %%
arr = [True, False, True]
# If any element in array is True then it will print True else False
print(any(arr))

# If all elements in array is True then it will print True else False
print(all(arr))
# Out:
# True
# False

# %%
arr = [1,6,1,7]

print(arr.count(1))
# Out:
# 2

# %%
# def count_element_in_list(arr, element):
#     counter = 0
#     for i in range(0, len(arr)):
#         if(arr[i] == element):
#             counter +=1
#     return counter

def count_element_in_list(arr, element):
    counter = 0
    for i in arr:
        if(i == element):
            counter +=1
    return counter
# Out:
# 5

# %%
value = count_element_in_list(arr = [1,2,3,4,5,6,7,8,9,33,3,3,3,3], element= 3)
print(value)
# Out:
# 5

# %%
arr = [5,6,1,3]

for key, value in enumerate(arr):
    print("{"+ str(key)+" , "+str(value)+"}")
# Out:
# {0 , 5}
# {1 , 6}
# {2 , 1}
# {3 , 3}

# %%
print(list(enumerate(arr)))
# Out:
# [(0, 5), (1, 6), (2, 1), (3, 3)]

# %%
arr = [5,6,1]

print(list(reversed(arr)))
# Out:
# [1, 6, 5]

# %%
arr = list(range(5))
print(arr)
# Out:
# [0, 1, 2, 3, 4]

# %%
print(list(range(1,15,3)))
print(arr)
# Out:
# [1, 4, 7, 10, 13]
# [0, 1, 2, 3, 4]
