# %%
from collections import OrderedDict

# %%
od = OrderedDict([])

# %%
print(od)
# Out:
# OrderedDict()

# %%
od = OrderedDict([( 1, 'teja'),( 3, 'kumar'),( 2, 'sai')])

# %%
print(od)
# Out:
# OrderedDict({1: 'teja', 3: 'kumar', 2: 'sai'})

# %%
print(od[1])
# Out:
# teja

# %%
print(od[10])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 print(od[10])
#
# KeyError: 10

# %%
if 10 in od:
    print(od[10].value())
else:
    print("Not in the Dict")
# Out:
# Not in the Dict

# %%
print(od)
# Out:
# OrderedDict({1: 'teja', 3: 'kumar', 2: 'sai'})

# %%
od[10] = 'messi'

# %%
od.move_to_end(1)

# %%
print(od)
# Out:
# OrderedDict({3: 'kumar', 2: 'sai', 10: 'messi', 1: 'teja'})

# %%
od.move_to_end([1, 3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 od.move_to_end([1, 3])
#
# TypeError: unhashable type: 'list'

# %%
od.move_to_end(1, last=False)

# %%
od
# Out:
# OrderedDict([(1, 'teja'), (3, 'kumar'), (2, 'sai'), (10, 'messi')])

# %%
od.popitem()
# Out:
# (10, 'messi')

# %%
print(od)
# Out:
# OrderedDict({1: 'teja', 3: 'kumar', 2: 'sai'})

# %%
od.pop(7)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 od.pop(7)
#
# KeyError: 7
